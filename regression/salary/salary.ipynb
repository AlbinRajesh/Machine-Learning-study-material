# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("salary.csv")
df = pd.DataFrame(data)
df
# Out:
#     YearsExperience  Salary
# 0               1.1   39343
# 1               1.3   46205
# 2               1.5   37731
# 3               2.0   43525
# 4               2.2   39891
# 5               2.9   56642
# 6               3.0   60150
# 7               3.2   54445
# 8               3.2   64445
# 9               3.7   57189
# 10              3.9   63218
# 11              4.0   55794
# 12              4.0   56957
# 13              4.1   57081
# 14              4.5   61111
# 15              4.9   67938
# 16              5.1   66029
# 17              5.3   83088
# 18              5.9   81363
# 19              6.0   93940
# 20              6.8   91738
# 21              7.1   98273
# 22              7.9  101302
# 23              8.2  113812
# 24              8.7  109431
# 25              9.0  105582
# 26              9.5  116969
# 27              9.6  112635
# 28             10.3  122391
# 29             10.5  121872
# 30             11.2  127345
# 31             11.5  126756
# ...

# %%
df.isna().sum()
# Out:
# YearsExperience    0
# Salary             0
# dtype: int64

# %%
df.dtypes
# Out:
# YearsExperience    float64
# Salary               int64
# dtype: object

# %%
x = df.iloc[:, :-1]  
x
y = df.iloc[:, -1]
y
# Out:
# 0      39343
# 1      46205
# 2      37731
# 3      43525
# 4      39891
# 5      56642
# 6      60150
# 7      54445
# 8      64445
# 9      57189
# 10     63218
# 11     55794
# 12     56957
# 13     57081
# 14     61111
# 15     67938
# 16     66029
# 17     83088
# 18     81363
# 19     93940
# 20     91738
# 21     98273
# 22    101302
# 23    113812
# 24    109431
# 25    105582
# 26    116969
# 27    112635
# 28    122391
# 29    121872
# 30    127345
# 31    126756
# 32    128765
# 33    135675
# 34    139465
# Name: Salary, dtype: int64

# %%
from matplotlib import pyplot as plt
plt.scatter(x,y,color ="black")
plt.xlabel("Years of Experience")
plt.ylabel("Salary")
plt.title("Salary vs Years of Experience")  
plt.show()

# %%
from sklearn.model_selection import train_test_split
x_train,x_test, y_train, y_test = train_test_split(x, y, test_size=0.2)

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()  
model.fit(x_train, y_train)  # Reshaping because sklearn expects 2D array for features
# Out:
# LinearRegression()

# %%
y_pred = model.predict(x_test)
y_pred
# Out:
# array([135905.35902707, 100015.79384016, 118398.25405784,  39616.28169633,
#         41366.99219326, 111395.41207015, 128902.51703938])

# %%
y_test.values
# Out:
# array([128765, 113812, 122391,  46205,  37731, 116969, 126756])

# %%
from sklearn.metrics import mean_absolute_error
print("Mean Absolute Error:", mean_absolute_error(y_test, y_pred))
# Out:
# Mean Absolute Error: 6124.875227887679

# %%
print(model.coef_)# it is the slope m
# Out:
# [8753.55248461]

# %%
print(model.intercept_) # it is the intercept c
# Out:
# 28236.663466337122

# %%
#Perfomance evaluations
#-------------------------------

# Mean absolute error
# mean squared error
# root mean squared error
# R - squared

# %%
# Evaluation metrics of regression
from sklearn.metrics import mean_absolute_error
error  = mean_absolute_error(y_test, y_pred)
error
# Out:
# 6124.875227887679

# %%
#Mean Squared Error
#---------------------
#y = actual 
#y = predicted
#error = y-y_
#squared error  = (y-y_)^2
#Mean squared error = 1/n E(y-y_)^2

# %%
from sklearn.metrics import mean_squared_error
mse = mean_squared_error(y_test,y_pred)
mse
# Out:
# 49938016.78935255

# %%
#Root Mean Square error
#-----------------------
#it takes the root of mean squared error
#y = actual 
#y = predicted
#error = y-y_
#squared error  = (y-y_)^2
#Mean squared error = 1/n E(y-y_)^2
#root mean squared error =

# %% [markdown]
# MAPE >>>  Total percentage of mean absaloute error >>> lower
# R2 - score >>> higher
# If this 2 things are okay we can say that our model performance is good
# If mean_absolute_percentafe_error is less and r2 is high the model is good

# %%
from sklearn.metrics import mean_absolute_percentage_error
mape = mean_absolute_percentage_error(y_test,y_pred)
mape
# Out:
# 0.0732632621998713

# %%
from sklearn.metrics import r2_score
r = r2_score(y_test,y_pred)
r
# Out:
# 0.9623594380259216
