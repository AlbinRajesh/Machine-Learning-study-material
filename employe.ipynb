# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("employe.csv")
df
# Out:
#       Education  JoiningYear       City  PaymentTier  Age  Gender EverBenched  \
# 0     Bachelors         2017  Bangalore            3   34    Male          No
# 1     Bachelors         2013       Pune            1   28  Female          No
# 2     Bachelors         2014  New Delhi            3   38  Female          No
# 3       Masters         2016  Bangalore            3   27    Male          No
# 4       Masters         2017       Pune            3   24    Male         Yes
# ...         ...          ...        ...          ...  ...     ...         ...
# 4648  Bachelors         2013  Bangalore            3   26  Female          No
# 4649    Masters         2013       Pune            2   37    Male          No
# 4650    Masters         2018  New Delhi            3   27    Male          No
# 4651  Bachelors         2012  Bangalore            3   30    Male         Yes
# 4652  Bachelors         2015  Bangalore            3   33    Male         Yes
#
# ...

# %%
df.head(5)
# Out:
#    Education  JoiningYear       City  PaymentTier  Age  Gender EverBenched  \
# 0  Bachelors         2017  Bangalore            3   34    Male          No
# 1  Bachelors         2013       Pune            1   28  Female          No
# 2  Bachelors         2014  New Delhi            3   38  Female          No
# 3    Masters         2016  Bangalore            3   27    Male          No
# 4    Masters         2017       Pune            3   24    Male         Yes
#
#    ExperienceInCurrentDomain  LeaveOrNot
# 0                          0           0
# 1                          3           1
# 2                          2           0
# 3                          5           1
# 4                          2           1

# %%
df.dtypes
# Out:
# Education                    object
# JoiningYear                   int64
# City                         object
# PaymentTier                   int64
# Age                           int64
# Gender                       object
# EverBenched                  object
# ExperienceInCurrentDomain     int64
# LeaveOrNot                    int64
# dtype: object

# %%
df.shape
# Out:
# (4653, 9)

# %%
df["City"].unique()
# Out:
# array(['Bangalore', 'Pune', 'New Delhi'], dtype=object)

# %%
# df[df["City"]=="Bangalore"].count()
df.groupby("City").count()
# Out:
#            Education  JoiningYear  PaymentTier   Age  Gender  EverBenched  \
# City
# Bangalore       2228         2228         2228  2228    2228         2228
# New Delhi       1157         1157         1157  1157    1157         1157
# Pune            1268         1268         1268  1268    1268         1268
#
#            ExperienceInCurrentDomain  LeaveOrNot
# City
# Bangalore                       2228        2228
# New Delhi                       1157        1157
# Pune                            1268        1268

# %%
df[df["Education"]=="Masters"]
# Out:
#      Education  JoiningYear       City  PaymentTier  Age  Gender EverBenched  \
# 3      Masters         2016  Bangalore            3   27    Male          No
# 4      Masters         2017       Pune            3   24    Male         Yes
# 9      Masters         2017  New Delhi            2   37    Male          No
# 10     Masters         2012  Bangalore            3   27    Male          No
# 21     Masters         2017  New Delhi            2   28    Male          No
# ...        ...          ...        ...          ...  ...     ...         ...
# 4618   Masters         2017  New Delhi            3   38  Female          No
# 4636   Masters         2014  New Delhi            3   37  Female          No
# 4645   Masters         2017       Pune            2   31  Female          No
# 4649   Masters         2013       Pune            2   37    Male          No
# 4650   Masters         2018  New Delhi            3   27    Male          No
#
#       ExperienceInCurrentDomain  LeaveOrNot
# ...

# %%
df.groupby("Gender").count()
# Out:
#         Education  JoiningYear  City  PaymentTier   Age  EverBenched  \
# Gender
# Female       1875         1875  1875         1875  1875         1875
# Male         2778         2778  2778         2778  2778         2778
#
#         ExperienceInCurrentDomain  LeaveOrNot
# Gender
# Female                       1875        1875
# Male                         2778        2778

# %%
df[df["ExperienceInCurrentDomain"]>3]
# Out:
#       Education  JoiningYear       City  PaymentTier  Age  Gender EverBenched  \
# 3       Masters         2016  Bangalore            3   27    Male          No
# 10      Masters         2012  Bangalore            3   27    Male          No
# 12    Bachelors         2018       Pune            3   32    Male         Yes
# 14    Bachelors         2012  Bangalore            3   37    Male          No
# 17    Bachelors         2014       Pune            3   34    Male          No
# ...         ...          ...        ...          ...  ...     ...         ...
# 4642  Bachelors         2012  Bangalore            3   36  Female          No
# 4643  Bachelors         2013  Bangalore            3   31  Female          No
# 4648  Bachelors         2013  Bangalore            3   26  Female          No
# 4650    Masters         2018  New Delhi            3   27    Male          No
# 4652  Bachelors         2015  Bangalore            3   33    Male         Yes
#
# ...

# %%
df[df["EverBenched"]=="No"]
# Out:
#       Education  JoiningYear       City  PaymentTier  Age  Gender EverBenched  \
# 0     Bachelors         2017  Bangalore            3   34    Male          No
# 1     Bachelors         2013       Pune            1   28  Female          No
# 2     Bachelors         2014  New Delhi            3   38  Female          No
# 3       Masters         2016  Bangalore            3   27    Male          No
# 5     Bachelors         2016  Bangalore            3   22    Male          No
# ...         ...          ...        ...          ...  ...     ...         ...
# 4646  Bachelors         2013  Bangalore            3   25  Female          No
# 4647  Bachelors         2016       Pune            3   30    Male          No
# 4648  Bachelors         2013  Bangalore            3   26  Female          No
# 4649    Masters         2013       Pune            2   37    Male          No
# 4650    Masters         2018  New Delhi            3   27    Male          No
#
# ...

# %%
df[df["JoiningYear"]>2015]
# Out:
#       Education  JoiningYear       City  PaymentTier  Age  Gender EverBenched  \
# 0     Bachelors         2017  Bangalore            3   34    Male          No
# 3       Masters         2016  Bangalore            3   27    Male          No
# 4       Masters         2017       Pune            3   24    Male         Yes
# 5     Bachelors         2016  Bangalore            3   22    Male          No
# 7     Bachelors         2016  Bangalore            3   34  Female          No
# ...         ...          ...        ...          ...  ...     ...         ...
# 4639  Bachelors         2017  Bangalore            3   28    Male          No
# 4641  Bachelors         2016  Bangalore            1   33  Female          No
# 4645    Masters         2017       Pune            2   31  Female          No
# 4647  Bachelors         2016       Pune            3   30    Male          No
# 4650    Masters         2018  New Delhi            3   27    Male          No
#
# ...

# %%
df.groupby("City")["Age"].mean()
# Out:
# City
# Bangalore    29.594255
# New Delhi    29.121003
# Pune         29.288644
# Name: Age, dtype: float64

# %%
df.groupby("Gender")["ExperienceInCurrentDomain"].mean()
# Out:
# Gender
# Female    2.889067
# Male      2.916847
# Name: ExperienceInCurrentDomain, dtype: float64

# %%
df.groupby("PaymentTier")["PaymentTier"].count()
# Out:
# PaymentTier
# 1     243
# 2     918
# 3    3492
# Name: PaymentTier, dtype: int64

# %%
df["JoiningYear"].min()
df["JoiningYear"].max()
# Out:
# np.int64(2018)

# %%
df.groupby("EverBenched")["ExperienceInCurrentDomain"].mean()
# Out:
# EverBenched
# No     2.904910
# Yes    2.912134
# Name: ExperienceInCurrentDomain, dtype: float64

# %%
counts = df.groupby("City").count()
counts
# Out:
#            Education  JoiningYear  PaymentTier   Age  Gender  EverBenched  \
# City
# Bangalore       2228         2228         2228  2228    2228         2228
# New Delhi       1157         1157         1157  1157    1157         1157
# Pune            1268         1268         1268  1268    1268         1268
#
#            ExperienceInCurrentDomain  LeaveOrNot
# City
# Bangalore                       2228        2228
# New Delhi                       1157        1157
# Pune                            1268        1268

# %%
# Find the city with the highest number of employees
city_counts = df["City"].value_counts()
high = city_counts.idxmax()
high
# Out:
# 'Bangalore'

# %%
df.groupby("LeaveOrNot")["Age"].mean()
# Out:
# LeaveOrNot
# 0    29.571896
# 1    29.052500
# Name: Age, dtype: float64

# %%
left_emp =(df["LeaveOrNot"]==1).sum()
total_emp = len(df)
'''(df["LeaveOrNot"] == 1) → Boolean Series (True if left, False otherwise)
.sum() → Counts the True values → total employees who left
Divide by total employees and multiply by 100 → percentage'''

# %%
left =(left_emp/total_emp)*100
left
# Out:
# np.float64(34.38641736514077)

# %%
left =  df[df['LeaveOrNot'] == 1]
left_edu = left.groupby("Education")["Education"].count()
left_edu
# Out:
# Education
# Bachelors    1129
# Masters       426
# PHD            45
# Name: Education, dtype: int64
