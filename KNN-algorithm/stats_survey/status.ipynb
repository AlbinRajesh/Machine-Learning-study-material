# %%
import pandas as pd
import numpy as np

# %%
df =  pd.read_csv("Stats survey.csv")
df
# Out:
#                       Timestamp Your Sex?  \
# 0     2024/03/07 5:12:01 pm EET    Female
# 1     2024/03/07 5:12:08 pm EET      Male
# 2     2024/03/07 5:12:25 pm EET      Male
# 3     2024/03/07 5:12:28 pm EET      Male
# 4     2024/03/07 5:13:00 pm EET    Female
# ..                          ...       ...
# 401  2024/03/12 11:05:33 am EET    Female
# 402   2024/03/12 3:26:14 pm EET    Female
# 403  2024/03/13 10:32:19 pm EET    Female
# 404  2024/03/13 10:32:27 pm EET      Male
# 405  2024/03/16 10:30:36 pm EET    Female
#
#      Your Matric (grade 12) Average/ GPA (in %)  \
# 0                                          76.0
# 1                                          89.0
# 2                                          76.0
# 3                                          89.0
# 4                                          74.0
# ..                                          ...
# 401                                        74.0
# 402                                        73.0
# ...

# %%
df["Your Sex?"]  = df["Your Sex?"].fillna("Male")
df.isna().sum()
# Out:
# Timestamp                                                                                             0
# Your Sex?                                                                                             0
# Your Matric (grade 12) Average/ GPA (in %)                                                            7
# What year were you in last year (2023) ?                                                             73
# What faculty does your degree fall under?                                                             7
# Your 2023 academic year average/GPA in % (Ignore if you are 2024 1st year student)                   86
# Your Accommodation Status Last Year (2023)                                                           23
# Monthly Allowance in 2023                                                                            31
# Were you on scholarship/bursary in 2023?                                                              8
# ...

# %%
from sklearn.impute import SimpleImputer
col = ["Your Matric (grade 12) Average/ GPA (in %)"]
col_imputer = SimpleImputer(strategy="mean")
df[col] = col_imputer.fit_transform(df[col])
df[col].dtypes
# Out:
# Your Matric (grade 12) Average/ GPA (in %)    float64
# dtype: object

# %%
df.isna().sum()
year = ["What year were you in last year (2023) ?"]
obj_imputer = SimpleImputer(strategy="most_frequent")
df[year] = obj_imputer.fit_transform(df[year])

# %%
df.isna().sum()
# Out:
# Timestamp                                                                                             0
# Your Sex?                                                                                             0
# Your Matric (grade 12) Average/ GPA (in %)                                                            0
# What year were you in last year (2023) ?                                                              0
# What faculty does your degree fall under?                                                             7
# Your 2023 academic year average/GPA in % (Ignore if you are 2024 1st year student)                   86
# Your Accommodation Status Last Year (2023)                                                           23
# Monthly Allowance in 2023                                                                            31
# Were you on scholarship/bursary in 2023?                                                              8
# ...

# %%
col = ["What faculty does your degree fall under?"]
df[col] = obj_imputer.fit_transform(df[col])

# %%
df.isna().sum()
df["Your 2023 academic year average/GPA in % (Ignore if you are 2024 1st year student)"]
# Out:
# 0      72.0
# 1      75.0
# 2      55.0
# 3      84.0
# 4      52.0
#        ...
# 401     NaN
# 402    58.0
# 403     NaN
# 404     NaN
# 405    63.0
# Name: Your 2023 academic year average/GPA in % (Ignore if you are 2024 1st year student), Length: 406, dtype: float64

# %%
col = ["Your 2023 academic year average/GPA in % (Ignore if you are 2024 1st year student)"]
df[col] = col_imputer.fit_transform(df[col])

df.isna().sum()
# Out:
# Timestamp                                                                                             0
# Your Sex?                                                                                             0
# Your Matric (grade 12) Average/ GPA (in %)                                                            0
# What year were you in last year (2023) ?                                                              0
# What faculty does your degree fall under?                                                             0
# Your 2023 academic year average/GPA in % (Ignore if you are 2024 1st year student)                    0
# Your Accommodation Status Last Year (2023)                                                           23
# Monthly Allowance in 2023                                                                            31
# Were you on scholarship/bursary in 2023?                                                              8
# ...

# %%
col = ["Your Accommodation Status Last Year (2023)"] 
df[col] = obj_imputer.fit_transform(df[col])
df.isna().sum()
# Out:
# Timestamp                                                                                             0
# Your Sex?                                                                                             0
# Your Matric (grade 12) Average/ GPA (in %)                                                            0
# What year were you in last year (2023) ?                                                              0
# What faculty does your degree fall under?                                                             0
# Your 2023 academic year average/GPA in % (Ignore if you are 2024 1st year student)                    0
# Your Accommodation Status Last Year (2023)                                                            0
# Monthly Allowance in 2023                                                                            31
# Were you on scholarship/bursary in 2023?                                                              8
# ...

# %%
col = ["Monthly Allowance in 2023"]
df[col] = obj_imputer.fit_transform(df[col])

# %%
col = ["Were you on scholarship/bursary in 2023?"]
df[col] = obj_imputer.fit_transform(df[col])

# %%
df.isna().sum()
# Out:
# Timestamp                                                                                            0
# Your Sex?                                                                                            0
# Your Matric (grade 12) Average/ GPA (in %)                                                           0
# What year were you in last year (2023) ?                                                             0
# What faculty does your degree fall under?                                                            0
# Your 2023 academic year average/GPA in % (Ignore if you are 2024 1st year student)                   0
# Your Accommodation Status Last Year (2023)                                                           0
# Monthly Allowance in 2023                                                                            0
# Were you on scholarship/bursary in 2023?                                                             0
# ...

# %%
df["Additional amount of studying (in hrs) per week"]
col = ["Additional amount of studying (in hrs) per week"]
df[col] = obj_imputer.fit_transform(df[col])

# %%
df.isna().sum()
# Out:
# Timestamp                                                                                            0
# Your Sex?                                                                                            0
# Your Matric (grade 12) Average/ GPA (in %)                                                           0
# What year were you in last year (2023) ?                                                             0
# What faculty does your degree fall under?                                                            0
# Your 2023 academic year average/GPA in % (Ignore if you are 2024 1st year student)                   0
# Your Accommodation Status Last Year (2023)                                                           0
# Monthly Allowance in 2023                                                                            0
# Were you on scholarship/bursary in 2023?                                                             0
# ...

# %%
last_col = ["On a night out, how many alcoholic drinks do you consume?","How many classes do you miss per week due to alcohol reasons, (i.e: being hungover or too tired?)","How many modules have you failed thus far into your studies?","Are you currently in a romantic relationship?","Do your parents approve alcohol consumption?","How strong is your relationship with your parent/s?"]
# df["How often do you go out partying/socialising during the week? "]
# df["On a night out, how many alcoholic drinks do you consume?"]
# df["How many classes do you miss per week due to alcohol reasons, (i.e: being hungover or too tired?)"]
# df["How many modules have you failed thus far into your studies?"]
# df["Are you currently in a romantic relationship?"]
# df["Do your parents approve alcohol consumption?"]
# df["How strong is your relationship with your parent/s?"]
df[last_col] = obj_imputer.fit_transform(df[last_col])

# %%
df.isna().sum()
df["How often do you go out partying/socialising during the week? "]
# Out:
# 0      Only weekends
# 1      Only weekends
# 2                  2
# 3                  3
# 4      Only weekends
#            ...
# 401                3
# 402                1
# 403                2
# 404               4+
# 405    Only weekends
# Name: How often do you go out partying/socialising during the week? , Length: 406, dtype: object

# %%
col = ["How often do you go out partying/socialising during the week? "]
df[col] = obj_imputer.fit_transform(df[col])

# %%
df.isna().sum()
# Out:
# Timestamp                                                                                            0
# Your Sex?                                                                                            0
# Your Matric (grade 12) Average/ GPA (in %)                                                           0
# What year were you in last year (2023) ?                                                             0
# What faculty does your degree fall under?                                                            0
# Your 2023 academic year average/GPA in % (Ignore if you are 2024 1st year student)                   0
# Your Accommodation Status Last Year (2023)                                                           0
# Monthly Allowance in 2023                                                                            0
# Were you on scholarship/bursary in 2023?                                                             0
# ...

# %%
from matplotlib import pyplot as plt

# %%
x = df["What year were you in last year (2023) ?"]
y = df["Your Matric (grade 12) Average/ GPA (in %)"]
plt.plot(x,y)
