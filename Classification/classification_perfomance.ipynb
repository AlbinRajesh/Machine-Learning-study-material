# %% [markdown]
# confusion matrix
# -------------------
# TP TN FP FN
# f1-score, recall ,precision
# TP = 40
# TN = 30
# FP = 25
# FN = 20
# precision = TP /(TP + FP)  = 40 / 65 (from all predicted positive how many are correct)
# recall = TP/TP + FN   = 40 / 60 (from all actual positive )
# f1 _ score = 2 * (precision * recall)
#             ------------------------------ = 0.63 (mean of precision,recall)
#                 (precision + recall)
#
#
# For imporving  the model
# --------------------------
# Change the random state
#
# training data size increase
#
# selecting  input fetures
