# %% [markdown]
# In classification our dataset made up of different labels (classes)
#
# Pure Data
# ------------
# if all the rows contains same class its a pure one
#
# Impure Data
# ------------
# if all the sample contains both two classes its called impure
#
# we need  to calculate the impurity to find how mixed the data is
# #it has been used in the decision tree algorithm
# eg)
#         target        target                     target          target        target
#         yes            yes                        yes             yes            no
#         yes            yes                        yes             no             no
#         yes            yes                        no              no             no
#         yes            no                         no              no             no
# this is pure          this is the impure          this one contains
# all points under same   it contains no               the maximum impurity
#                             different categories
# Gini,Entropy
# -------------
# we used these terms to identify the impurity in data contains more than two classification
#
# we use them for measuring the impurity in the different datasets
#
# so these can be introduced as measuring of impurity or measure of randomness

# %%
Decision Tree Algorithm
-------------------------
used in  classification,regression
===================================
root >>> single value
node >>> contains multiple values
leaf >>> contains multiple values

Tree >>> root,node,leaf
-----------------------
input fetures >>>>>>> node
target >>>>>>>>>>>>>> leaf
root >>>>>>>>>>>>>>>> output(prediction)
