# %% [markdown]
# Polynomial Regression
# ----------------------
# If the model in multiple linear regression is not performing  well we can use the polynomial regression

# %%
# Polynomial regression
y = mx + c
y = mlx1 +
... + c
polynomial equation = second degree >> ax^2 + bx + c (here we are expanding the independent variable
to a 2 feature)
= ax^3 + bx^2 + cx + d (here expanding upto 3 feauture(degree))
