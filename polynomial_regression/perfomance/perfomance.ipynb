# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("Student_Performance.csv")
df
# Out:
#       Hours Studied  Previous Scores Extracurricular Activities  Sleep Hours  \
# 0                 7               99                        Yes            9
# 1                 4               82                         No            4
# 2                 8               51                        Yes            7
# 3                 5               52                        Yes            5
# 4                 7               75                         No            8
# ...             ...              ...                        ...          ...
# 9995              1               49                        Yes            4
# 9996              7               64                        Yes            8
# 9997              6               83                        Yes            8
# 9998              9               97                        Yes            7
# 9999              7               74                         No            8
#
# ...

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import MinMaxScaler
x = df.iloc[:,:-1]
x
y = df.iloc[:,-1]
y
# Out:
# 0       91.0
# 1       65.0
# 2       45.0
# 3       36.0
# 4       66.0
#         ...
# 9995    23.0
# 9996    58.0
# 9997    74.0
# 9998    95.0
# 9999    64.0
# Name: Performance Index, Length: 10000, dtype: float64

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.3)

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()

# Fit only on training column, transform both
x_train["Extracurricular Activities"] = le.fit_transform(
    x_train["Extracurricular Activities"]
)

x_test["Extracurricular Activities"] = le.transform(
    x_test["Extracurricular Activities"]
)

# %%
scaler = MinMaxScaler()
x_train = scaler.fit_transform(x_train)
x_test = scaler.transform(x_test)

# %%
from sklearn.linear_model import LinearRegression
li = LinearRegression()
li.fit(x_train,y_train)
y_pred = li.predict(x_test)
y_pred
# Out:
# array([23.77216101, 29.34593839, 36.06521297, ..., 53.83673517,
#        49.97631459, 35.19343378], shape=(3000,))

# %%
from sklearn.metrics import mean_absolute_percentage_error,r2_score
print(mean_absolute_percentage_error(y_test,y_pred))
print(r2_score(y_test,y_pred))
# Out:
# 0.03476822213131166
# 0.9890540541526107

# %%
from sklearn.preprocessing import PolynomialFeatures
from sklearn.preprocessing import PolynomialFeatures
fetures = PolynomialFeatures(degree=2)
x_poly = fetures.fit_transform(x)
model1 = LinearRegression()
model1.fit(x_poly,y)
poly_pred = model1.predict(x_poly)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_18716\122411898.py in ?()
#       1 from sklearn.preprocessing import PolynomialFeatures
#       2 from sklearn.preprocessing import PolynomialFeatures
#       3 fetures = PolynomialFeatures(degree=2)
# ----> 4 x_poly = fetures.fit_transform(x)
#       5 model1 = LinearRegression()
#       6 model1.fit(x_poly,y)
#       7 poly_pred = model1.predict(x_poly)
#
# c:\Users\LENOVO\Documents\ML-STDY\venv\Lib\site-packages\sklearn\utils\_set_output.py in ?(self, X, *args, **kwargs)
#     314     @wraps(f)
#     315     def wrapped(self, X, *args, **kwargs):
# --> 316         data_to_wrap = f(self, X, *args, **kwargs)
#     317         if isinstance(data_to_wrap, tuple):
#     318             # only wrap the first output for cross decomposition
#     319             return_tuple = (
#
# ...

# %%
from sklearn.preprocessing import PolynomialFeatures
fetures = PolynomialFeatures(degree=2)
# x_poly = x_train.iloc[:,:-1]
# x_poly
# x_poly = fetures.fit_transform(x_train)
# model1 = LinearRegression()
# model1.fit(x_poly,y)
# # poly_pred = model1.predict(x_poly)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[41], line 3
#       1 from sklearn.preprocessing import PolynomialFeatures
#       2 fetures = PolynomialFeatures(degree=2)
# ----> 3 x_poly = x_train.iloc[:,:-1]
#       4 x_poly
#       5 # x_poly = fetures.fit_transform(x_train)
#       6 # model1 = LinearRegression()
#       7 # model1.fit(x_poly,y)
#       8 # # poly_pred = model1.predict(x_poly)
#
# AttributeError: 'numpy.ndarray' object has no attribute 'iloc'
