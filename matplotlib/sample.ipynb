# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot

# %%
velocity = [12,15,20,30]
displacement = [10,20,30,40]
pyplot.scatter(velocity,displacement,color = "r")

# %%
#Bar Chart
#==========
x = [5,7,8,9,10]
y = [3,7,4,8,9]
pyplot.bar(x,y)
# Out:
# <BarContainer object of 5 artists>

# %%
country = ["india","australia","china","japan","pakisthan"]
count = [1000,3000,2000,1500,1200]
pyplot.bar(x,y)
pyplot.xlabel("Country")
pyplot.ylabel("Count")
pyplot.title("Statics")
# Out:
# Text(0.5, 1.0, 'Statics')

# %%
marks =[50,40,45,55,70,80,65,90,92,63]
pyplot.hist(marks,color="skyblue",edgecolor = "black")
pyplot.xlabel("mark range")
pyplot.ylabel("number of students")
pyplot.xticks(range(40,100,5))
pyplot.show()

#histogram
# --------------
# Used for the distribustion of numerical data (marks,ages,salaries)
# here we seea histogram dicivided into 7 bins (intervels), each bar heights show how many students
# scores how much marks
