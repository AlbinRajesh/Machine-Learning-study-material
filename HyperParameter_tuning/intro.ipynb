# %% [markdown]
# hyper parameter tuning
# -----------------------
#
# the settings whoch are given to model before training
#
# they decide how the model learns
#
# KNN K= 5 k = 7
#
# random forest   n_estimators = 100      300        1000
#
# polynomial    X   degree 3   ax2 + bx + c    mape  2
#
# Trying different combination of hyper parameters and selecting the best one
#
#
# correlation and chi square
# ---------------------------
# correlation----
#
# Used to identify the relation between each columns(numeric_columns)
# it also results which column  will affect the target mostly
# the highest value in correlation is 1 and lowest value is 0, there will be negative also
#
# df.corr()
#
#
# Chi Square
# ------------------
#
# To identify the relation between object columns - chi square
